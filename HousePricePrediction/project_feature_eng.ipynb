# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model, kernel_ridge, svm

from dmba import adjusted_r2_score, AIC_score, BIC_score
from dmba import regressionSummary, exhaustive_search, backward_elimination, forward_selection, stepwise_selection

# %%
# importing dataset file
ds= pd.read_csv("F:/Junkyard/Studies/Data Science and Machine Learning/session_4/project_proposals/datasets/dataset2_houseprice/house_price.csv")

#ds.info()
#ds.describe()
#ds.head()

# %%
# extracting name of the columns (attributes) with differend data types

obj = (ds.dtypes == 'object')   # returns a dataframe that has column for index and corresponding
                        # True/False statement for second column (if data in the column is object)
object_cols = list(obj[obj].index) # obj[obj] returns rows with only True values and index method
                                    # return first column(name of the columns in original dataset)
print("Categorical variables:",len(object_cols))

#same for integers as for objects
int_ = (ds.dtypes == 'int64')
num_cols = list(int_[int_].index)
print("Integer variables:",len(num_cols))

#same for floats as for objects
fl = (ds.dtypes == 'float')
fl_cols = list(fl[fl].index)
print("Float variables:",len(fl_cols))
# Out:
# Categorical variables: 43
# Integer variables: 35
# Float variables: 3

# %%
#dummies (does not count NaN values if 'dummy_na' is false like it is by default)

ds2=ds[object_cols]
ds2d=pd.get_dummies(ds2,drop_first=True)            # drop_first=True parameter eliminates variables (we might not want to use that)
ds.drop(object_cols,axis=1,inplace=True)
ds=pd.concat([ds,ds2d],axis=1)

# %%
#filling NaN values (which are left after dummies), so that the model can work:

ds.fillna(value=0,inplace=True)

# %%
# Preparing dataset for feature engeneering and model selection:
from statistics import mean
predict='SalePrice'

X=(ds.drop([predict],axis=1))    #returns new dataframe, that doesn't have 'SalesPrice' in it
y=(ds[predict])             #returns true values for labels, that we want to predict or test

x_train,x_test,y_train,y_test=sklearn.model_selection.train_test_split(X,y,test_size=0.2)  #spliting into train/test samples

# %%
# Feature engineering
# 1 Backward elimination:
# General functions of ensemble:
def train_model(variables):
    model = linear_model.LinearRegression()
    model.fit(x_train[variables], y_train)
    return model
def score_model(model, variables):
    return AIC_score(y_train, model.predict(x_train[variables]), model)
# Assigning results:
allVariables = ds.drop(predict,axis=1).columns
best_model, best_variables = backward_elimination(allVariables, train_model, score_model, verbose=True)
# Out:
# Variables: Id, MSSubClass, LotFrontage, LotArea, OverallQual, OverallCond, YearBuilt, YearRemodAdd, MasVnrArea, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, TotRmsAbvGrd, Fireplaces, GarageYrBlt, GarageCars, GarageArea, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, MSZoning_FV, MSZoning_RH, MSZoning_RL, MSZoning_RM, Street_Pave, Alley_Pave, LotShape_IR2, LotShape_IR3, LotShape_Reg, LandContour_HLS, LandContour_Low, LandContour_Lvl, Utilities_NoSeWa, LotConfig_CulDSac, LotConfig_FR2, LotConfig_FR3, LotConfig_Inside, LandSlope_Mod, LandSlope_Sev, Neighborhood_Blueste, Neighborhood_BrDale, Neighborhood_BrkSide, Neighborhood_ClearCr, Neighborhood_CollgCr, Neighborhood_Crawfor, Neighborhood_Edwards, Neighborhood_Gilbert, Neighborhood_IDOTRR, Neighborhood_MeadowV, Neighborhood_Mitchel, Neighborhood_NAmes, Neighborhood_NPkVill, Neighborhood_NWAmes, Neighborhood_NoRidge, Neighborhood_NridgHt, Neighborhood_OldTown, Neighborhood_SWISU, Neighborhood_Sawyer, Neighborhood_SawyerW, Neighborhood_Somerst, Neighborhood_StoneBr, Neighborhood_Timber, Neighborhood_Veenker, Condition1_Feedr, Condition1_Norm, Condition1_PosA, Condition1_PosN, Condition1_RRAe, Condition1_RRAn, Condition1_RRNe, Condition1_RRNn, Condition2_Feedr, Condition2_Norm, Condition2_PosA, Condition2_PosN, Condition2_RRAe, Condition2_RRAn, Condition2_RRNn, BldgType_2fmCon, BldgType_Duplex, BldgType_Twnhs, BldgType_TwnhsE, HouseStyle_1.5Unf, HouseStyle_1Story, HouseStyle_2.5Fin, HouseStyle_2.5Unf, HouseStyle_2Story, HouseStyle_SFoyer, HouseStyle_SLvl, RoofStyle_Gable, RoofStyle_Gambrel, RoofStyle_Hip, RoofStyle_Mansard, RoofStyle_Shed, RoofMatl_CompShg, RoofMatl_Membran, RoofMatl_Metal, RoofMatl_Roll, RoofMatl_Tar&Grv, RoofMatl_WdShake, RoofMatl_WdShngl, Exterior1st_AsphShn, Exterior1st_BrkComm, Exterior1st_BrkFace, Exterior1st_CBlock, Exterior1st_CemntBd, Exterior1st_HdBoard, Exterior1st_ImStucc, Exterior1st_MetalSd, Exterior1st_Plywood, Exterior1st_Stone, Exterior1st_Stucco, Exterior1st_VinylSd, Exterior1st_Wd Sdng, Exterior1st_WdShing, Exterior2nd_AsphShn, Exterior2nd_Brk Cmn, Exterior2nd_BrkFace, Exterior2nd_CBlock, Exterior2nd_CmentBd, Exterior2nd_HdBoard, Exterior2nd_ImStucc, Exterior2nd_MetalSd, Exterior2nd_Other, Exterior2nd_Plywood, Exterior2nd_Stone, Exterior2nd_Stucco, Exterior2nd_VinylSd, Exterior2nd_Wd Sdng, Exterior2nd_Wd Shng, MasVnrType_BrkFace, MasVnrType_None, MasVnrType_Stone, ExterQual_Fa, ExterQual_Gd, ExterQual_TA, ExterCond_Fa, ExterCond_Gd, ExterCond_Po, ExterCond_TA, Foundation_CBlock, Foundation_PConc, Foundation_Slab, Foundation_Stone, Foundation_Wood, BsmtQual_Fa, BsmtQual_Gd, BsmtQual_TA, BsmtCond_Gd, BsmtCond_Po, BsmtCond_TA, BsmtExposure_Gd, BsmtExposure_Mn, BsmtExposure_No, BsmtFinType1_BLQ, BsmtFinType1_GLQ, BsmtFinType1_LwQ, BsmtFinType1_Rec, BsmtFinType1_Unf, BsmtFinType2_BLQ, BsmtFinType2_GLQ, BsmtFinType2_LwQ, BsmtFinType2_Rec, BsmtFinType2_Unf, Heating_GasA, Heating_GasW, Heating_Grav, Heating_OthW, Heating_Wall, HeatingQC_Fa, HeatingQC_Gd, HeatingQC_Po, HeatingQC_TA, CentralAir_Y, Electrical_FuseF, Electrical_FuseP, Electrical_Mix, Electrical_SBrkr, KitchenQual_Fa, KitchenQual_Gd, KitchenQual_TA, Functional_Maj2, Functional_Min1, Functional_Min2, Functional_Mod, Functional_Sev, Functional_Typ, FireplaceQu_Fa, FireplaceQu_Gd, FireplaceQu_Po, FireplaceQu_TA, GarageType_Attchd, GarageType_Basment, GarageType_BuiltIn, GarageType_CarPort, GarageType_Detchd, GarageFinish_RFn, GarageFinish_Unf, GarageQual_Fa, GarageQual_Gd, GarageQual_Po, GarageQual_TA, GarageCond_Fa, GarageCond_Gd, GarageCond_Po, GarageCond_TA, PavedDrive_P, PavedDrive_Y, PoolQC_Fa, PoolQC_Gd, Fence_GdWo, Fence_MnPrv, Fence_MnWw, MiscFeature_Othr, MiscFeature_Shed, MiscFeature_TenC, SaleType_CWD, SaleType_Con, SaleType_ConLD, SaleType_ConLI, SaleType_ConLw, SaleType_New, SaleType_Oth, SaleType_WD, SaleCond ...
# Start: score=28181.49
# Step: score=28174.43, remove BsmtFinSF1
# Step: score=28167.37, remove 1stFlrSF
# Step: score=28160.30, remove Condition2_RRAe
# Step: score=28153.24, remove RoofMatl_Membran
# Step: score=28146.18, remove RoofMatl_Roll
# Step: score=28139.12, remove Exterior1st_CBlock
# Step: score=28132.05, remove Exterior1st_Stone
# Step: score=28124.99, remove Exterior1st_ImStucc
# Step: score=28117.93, remove Heating_GasA
# Step: score=28110.86, remove Heating_OthW
# Step: score=28103.80, remove PoolQC_Fa
# Step: score=28096.74, remove MiscFeature_Shed
# Step: score=28089.67, remove SaleType_WD
# Step: score=28082.61, remove CentralAir_Y
# Step: score=28075.55, remove BsmtCond_TA
# Step: score=28068.49, remove Electrical_FuseF
# Step: score=28061.42, remove Electrical_Mix
# Step: score=28054.36, remove Exterior2nd_Other
# Step: score=28047.30, remove HouseStyle_2.5Unf
# Step: score=28040.24, remove HalfBath
# Step: score=28033.18, remove ExterCond_TA
# Step: score=28026.13, remove PavedDrive_P
# Step: score=28019.07, remove YrSold
# Step: score=28012.01, remove ExterCond_Po
# Step: score=28004.96, remove Neighborhood_MeadowV
# Step: score=27997.90, remove Neighborhood_ClearCr
# Step: score=27990.84, remove Exterior1st_AsphShn
# Step: score=27983.79, remove Functional_Min1
# Step: score=27976.74, remove Electrical_SBrkr
# Step: score=27969.70, remove FireplaceQu_Po
# Step: score=27962.65, remove BsmtFinType1_Rec
# Step: score=27955.61, remove Heating_Grav
# Step: score=27948.57, remove LotFrontage
# Step: score=27941.54, remove Exterior1st_BrkComm
# Step: score=27934.50, remove Exterior1st_WdShing
# Step: score=27927.45, remove Exterior2nd_ImStucc
# Step: score=27920.41, remove Exterior2nd_Brk Cmn
# Step: score=27913.37, remove Heating_GasW
# Step: score=27906.34, remove OpenPorchSF
# Step: score=27899.31, remove MiscVal
# Step: score=27892.28, remove Functional_Mod
# Step: score=27885.26, remove Condition1_RRNe
# Step: score=27878.25, remove BsmtFinType1_LwQ
# Step: score=27871.24, remove BsmtFinType2_GLQ
# Step: score=27864.24, remove MSZoning_RM
# Step: score=27857.24, remove Foundation_Stone
# Step: score=27850.25, remove RoofStyle_Hip
# Step: score=27843.25, remove LandSlope_Mod
# Step: score=27836.27, remove LowQualFinSF
# Step: score=27829.28, remove RoofStyle_Gable
# Step: score=27822.31, remove Exterior2nd_CBlock
# Step: score=27815.37, remove MSZoning_FV
# Step: score=27808.43, remove Condition1_PosA
# Step: score=27801.47, remove Exterior2nd_BrkFace
# Step: score=27794.55, remove SaleType_ConLw
# Step: score=27787.66, remove Neighborhood_Blueste
# Step: score=27780.78, remove Alley_Pave
# Step: score=27773.90, remove SaleType_ConLD
# Step: score=27767.02, remove HouseStyle_SFoyer
# Step: score=27760.10, remove MSSubClass
# Step: score=27753.06, remove BldgType_2fmCon
# Step: score=27746.19, remove BsmtHalfBath
# Step: score=27739.31, remove BsmtCond_Gd
# Step: score=27732.48, remove Fence_MnPrv
# Step: score=27725.64, remove MiscFeature_Othr
# Step: score=27718.80, remove HouseStyle_1.5Unf
# Step: score=27711.97, remove LotConfig_Inside
# Step: score=27705.20, remove SaleCondition_Family
# Step: score=27698.45, remove LandContour_Low
# Step: score=27691.70, remove Electrical_FuseP
# Step: score=27684.95, remove Exterior1st_HdBoard
# Step: score=27678.12, remove Exterior2nd_Plywood
# Step: score=27671.31, remove Exterior1st_Stucco
# Step: score=27664.47, remove Exterior1st_MetalSd
# Step: score=27657.70, remove Condition1_RRNn
# Step: score=27650.95, remove Neighborhood_BrDale
# Step: score=27644.23, remove Exterior2nd_Wd Shng
# Step: score=27637.46, remove Exterior2nd_HdBoard
# Step: score=27630.77, remove Neighborhood_BrkSide
# Step: score=27624.03, remove Condition2_PosA
# Step: score=27617.35, remove MasVnrType_Stone
# Step: score=27610.63, remove MasVnrType_BrkFace
# Step: score=27603.95, remove Heating_Wall
# Step: score=27597.25, remove GarageFinish_Unf
# Step: score=27590.60, remove Id
# Step: score=27583.92, remove BsmtFinType2_Rec
# Step: score=27577.36, remove Foundation_Slab
# Step: score=27570.72, remove BsmtFinType2_Unf
# Step: score=27564.13, remove HeatingQC_Fa
# Step: score=27557.55, remove HeatingQC_Po
# Step: score=27551.00, remove RoofStyle_Gambrel
# Step: score=27544.45, remove Neighborhood_SawyerW
# Step: score=27537.97, remove Exterior2nd_AsphShn
# Step: score=27531.45, remove PavedDrive_Y
# Step: score=27524.98, remove Street_Pave
# Step: score=27518.55, remove Neighborhood_Veenker
# Step: score=27512.12, remove Exterior2nd_Stone
# Step: score=27505.71, remove MiscFeature_TenC
# Step: score=27499.36, remove SaleType_ConLI
# Step: score=27493.03, remove 3SsnPorch
# Step: score=27486.81, remove Functional_Min2
# Step: score=27480.64, remove BsmtFinType2_LwQ
# Step: score=27474.40, remove BsmtFinType2_BLQ
# Step: score=27468.27, remove HouseStyle_SLvl
# Step: score=27462.16, remove Fence_GdWo
# Step: score=27456.09, remove Condition1_Feedr
# Step: score=27450.12, remove LotShape_IR2
# Step: score=27444.22, remove Condition1_RRAn
# Step: score=27438.30, remove Foundation_PConc
# Step: score=27431.62, remove Foundation_CBlock
# Step: score=27425.64, remove SaleCondition_Alloca
# Step: score=27419.69, remove SaleType_Oth
# Step: score=27413.82, remove Fence_MnWw
# Step: score=27407.92, remove EnclosedPorch
# Step: score=27402.06, remove Condition2_RRNn
# Step: score=27395.90, remove Condition2_RRAn
# Step: score=27389.43, remove RoofStyle_Shed
# Step: score=27382.80, remove Condition2_Norm
# Step: score=27376.05, remove Condition2_Feedr
# Step: score=27370.23, remove MSZoning_RH
# Step: score=27364.39, remove SaleCondition_AdjLand
# Step: score=27358.91, remove RoofStyle_Mansard
# Step: score=27353.41, remove HouseStyle_2Story
# Step: score=27347.94, remove BsmtFinType1_BLQ
# Step: score=27342.66, remove SaleType_CWD
# Step: score=27337.39, remove LandSlope_Sev
# Step: score=27332.18, remove Condition1_PosN
# Step: score=27326.97, remove Exterior1st_Plywood
# Step: score=27321.71, remove Neighborhood_NPkVill
# Step: score=27316.64, remove Exterior1st_Wd Sdng
# Step: score=27310.60, remove Exterior2nd_Wd Sdng
# Step: score=27305.31, remove Exterior1st_VinylSd
# Step: score=27300.38, remove Utilities_NoSeWa
# Step: score=27295.56, remove LotShape_Reg
# Step: score=27290.95, remove ExterCond_Gd
# Step: score=27286.33, remove FireplaceQu_Fa
# Step: score=27281.57, remove GarageCond_Gd
# Step: score=27275.34, remove GarageCond_Po
# Step: score=27269.32, remove GarageQual_Gd
# Step: score=27262.57, remove GarageQual_Po
# Step: score=27256.97, remove GarageCond_Fa
# Step: score=27250.85, remove GarageCond_TA
# Step: score=27245.30, remove GarageQual_TA
# Step: score=27240.12, remove FireplaceQu_TA
# Step: score=27234.62, remove FireplaceQu_Gd
# Step: score=27229.63, remove GarageQual_Fa
# Step: score=27224.84, remove BldgType_Duplex
# Step: score=27219.98, remove ExterCond_Fa
# Step: score=27214.68, remove BsmtCond_Po
# Step: score=27209.12, remove Functional_Maj2
# Step: score=27204.04, remove BsmtFinType1_Unf
# Step: score=27198.84, remove BsmtFinType1_GLQ
# Step: score=27194.05, remove Foundation_Wood
# Step: score=27189.30, remove ExterQual_Fa
# Step: score=27184.66, remove PoolArea
# Step: score=27179.57, remove PoolQC_Gd
# Step: score=27175.09, remove BsmtExposure_Mn
# Step: score=27170.77, remove HeatingQC_TA
# Step: score=27165.57, remove HeatingQC_Gd
# Step: score=27161.12, remove LotConfig_FR2
# Step: score=27156.83, remove GarageType_CarPort
# Step: score=27152.28, remove GarageType_BuiltIn
# Step: score=27145.88, remove GarageType_Detchd
# Step: score=27139.02, remove GarageType_Attchd
# Step: score=27132.60, remove GarageType_Basment
# Step: score=27128.38, remove Condition1_RRAe
# Step: score=27123.88, remove Neighborhood_CollgCr
# Step: score=27119.22, remove Exterior2nd_Stucco
# Step: score=27114.48, remove Exterior2nd_MetalSd
# Step: score=27110.22, remove LotConfig_FR3
# Step: score=27106.08, remove FullBath
# Step: score=27102.08, remove SaleType_Con
# Step: score=27098.28, remove Neighborhood_Gilbert
# Step: score=27093.70, remove GarageCars
# Step: score=27089.30, remove LotShape_IR3
# Step: score=27085.71, remove MasVnrType_None
# Step: score=27082.23, remove BsmtFullBath
# Step: score=27078.53, remove Neighborhood_SWISU
# Step: score=27074.74, remove Exterior2nd_VinylSd
# Step: score=27070.74, remove WoodDeckSF
# Step: score=27067.21, remove Neighborhood_IDOTRR
# Step: score=27063.82, remove Neighborhood_OldTown
# Step: score=27060.91, remove Neighborhood_Timber
# Step: score=27057.95, remove MoSold
# Step: score=27055.28, remove GarageFinish_RFn
# Step: score=27052.73, remove GarageYrBlt
# Step: score=27050.36, remove ScreenPorch
# Step: score=27047.41, remove BsmtFinSF2
# Step: score=27044.57, remove LandContour_Lvl
# Step: score=27039.91, remove LandContour_HLS
# Step: score=27038.82, remove Fireplaces
# Step: score=27037.97, remove Neighborhood_Sawyer
# Step: score=27037.25, remove TotRmsAbvGrd
# Step: score=27035.98, remove HouseStyle_2.5Fin
# Step: score=27035.50, remove LotConfig_CulDSac
# Step: score=27034.90, remove HouseStyle_1Story
# Step: score=27032.90, remove 2ndFlrSF
# Step: score=27031.58, remove BsmtExposure_No
# Step: score=27031.58, remove None

# %%
# 1 Backward Elimination Results:
print(best_variables)
regressionSummary(y, best_model.predict(ds[best_variables]))
# Out:
# ['LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtUnfSF', 'TotalBsmtSF', 'GrLivArea', 'BedroomAbvGr', 'KitchenAbvGr', 'GarageArea', 'MSZoning_RL', 'Neighborhood_Crawfor', 'Neighborhood_Edwards', 'Neighborhood_Mitchel', 'Neighborhood_NAmes', 'Neighborhood_NWAmes', 'Neighborhood_NoRidge', 'Neighborhood_NridgHt', 'Neighborhood_Somerst', 'Neighborhood_StoneBr', 'Condition1_Norm', 'Condition2_PosN', 'BldgType_Twnhs', 'BldgType_TwnhsE', 'RoofMatl_CompShg', 'RoofMatl_Metal', 'RoofMatl_Tar&Grv', 'RoofMatl_WdShake', 'RoofMatl_WdShngl', 'Exterior1st_BrkFace', 'Exterior1st_CemntBd', 'Exterior2nd_CmentBd', 'ExterQual_Gd', 'ExterQual_TA', 'BsmtQual_Fa', 'BsmtQual_Gd', 'BsmtQual_TA', 'BsmtExposure_Gd', 'KitchenQual_Fa', 'KitchenQual_Gd', 'KitchenQual_TA', 'Functional_Sev', 'Functional_Typ', 'SaleType_New', 'SaleCondition_Normal', 'SaleCondition_Partial']
#
# Regression statistics
#
#                       Mean Error (ME) : 936.4405
#        Root Mean Squared Error (RMSE) : 33727.5950
#             Mean Absolute Error (MAE) : 16219.0138
#           Mean Percentage Error (MPE) : -0.4231
# Mean Absolute Percentage Error (MAPE) : 9.5802

# %%
# Feature engineering:
# 2 Forward selection:
# COMMON CODE FOR METHODS 2 and 3 
# The initial model is the constant model - this requires special handling in train_model and score_model
def train_model(variables):
    if len(variables) == 0:
        return None
    model = linear_model.LinearRegression()
    model.fit(x_train[variables], y_train)
    return model
def score_model(model, variables):
    if len(variables) == 0:
        return AIC_score(y_train, [y_train.mean()] * len(y_train), model, df=1)
    return AIC_score(y_train, model.predict(x_train[variables]), model)

# %%
# 2 Assign results for Forward Selection:
best_model, best_variables = forward_selection(x_train.columns, train_model, score_model, verbose=True)
# Out:
# Variables: Id, MSSubClass, LotFrontage, LotArea, OverallQual, OverallCond, YearBuilt, YearRemodAdd, MasVnrArea, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, TotRmsAbvGrd, Fireplaces, GarageYrBlt, GarageCars, GarageArea, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, MSZoning_FV, MSZoning_RH, MSZoning_RL, MSZoning_RM, Street_Pave, Alley_Pave, LotShape_IR2, LotShape_IR3, LotShape_Reg, LandContour_HLS, LandContour_Low, LandContour_Lvl, Utilities_NoSeWa, LotConfig_CulDSac, LotConfig_FR2, LotConfig_FR3, LotConfig_Inside, LandSlope_Mod, LandSlope_Sev, Neighborhood_Blueste, Neighborhood_BrDale, Neighborhood_BrkSide, Neighborhood_ClearCr, Neighborhood_CollgCr, Neighborhood_Crawfor, Neighborhood_Edwards, Neighborhood_Gilbert, Neighborhood_IDOTRR, Neighborhood_MeadowV, Neighborhood_Mitchel, Neighborhood_NAmes, Neighborhood_NPkVill, Neighborhood_NWAmes, Neighborhood_NoRidge, Neighborhood_NridgHt, Neighborhood_OldTown, Neighborhood_SWISU, Neighborhood_Sawyer, Neighborhood_SawyerW, Neighborhood_Somerst, Neighborhood_StoneBr, Neighborhood_Timber, Neighborhood_Veenker, Condition1_Feedr, Condition1_Norm, Condition1_PosA, Condition1_PosN, Condition1_RRAe, Condition1_RRAn, Condition1_RRNe, Condition1_RRNn, Condition2_Feedr, Condition2_Norm, Condition2_PosA, Condition2_PosN, Condition2_RRAe, Condition2_RRAn, Condition2_RRNn, BldgType_2fmCon, BldgType_Duplex, BldgType_Twnhs, BldgType_TwnhsE, HouseStyle_1.5Unf, HouseStyle_1Story, HouseStyle_2.5Fin, HouseStyle_2.5Unf, HouseStyle_2Story, HouseStyle_SFoyer, HouseStyle_SLvl, RoofStyle_Gable, RoofStyle_Gambrel, RoofStyle_Hip, RoofStyle_Mansard, RoofStyle_Shed, RoofMatl_CompShg, RoofMatl_Membran, RoofMatl_Metal, RoofMatl_Roll, RoofMatl_Tar&Grv, RoofMatl_WdShake, RoofMatl_WdShngl, Exterior1st_AsphShn, Exterior1st_BrkComm, Exterior1st_BrkFace, Exterior1st_CBlock, Exterior1st_CemntBd, Exterior1st_HdBoard, Exterior1st_ImStucc, Exterior1st_MetalSd, Exterior1st_Plywood, Exterior1st_Stone, Exterior1st_Stucco, Exterior1st_VinylSd, Exterior1st_Wd Sdng, Exterior1st_WdShing, Exterior2nd_AsphShn, Exterior2nd_Brk Cmn, Exterior2nd_BrkFace, Exterior2nd_CBlock, Exterior2nd_CmentBd, Exterior2nd_HdBoard, Exterior2nd_ImStucc, Exterior2nd_MetalSd, Exterior2nd_Other, Exterior2nd_Plywood, Exterior2nd_Stone, Exterior2nd_Stucco, Exterior2nd_VinylSd, Exterior2nd_Wd Sdng, Exterior2nd_Wd Shng, MasVnrType_BrkFace, MasVnrType_None, MasVnrType_Stone, ExterQual_Fa, ExterQual_Gd, ExterQual_TA, ExterCond_Fa, ExterCond_Gd, ExterCond_Po, ExterCond_TA, Foundation_CBlock, Foundation_PConc, Foundation_Slab, Foundation_Stone, Foundation_Wood, BsmtQual_Fa, BsmtQual_Gd, BsmtQual_TA, BsmtCond_Gd, BsmtCond_Po, BsmtCond_TA, BsmtExposure_Gd, BsmtExposure_Mn, BsmtExposure_No, BsmtFinType1_BLQ, BsmtFinType1_GLQ, BsmtFinType1_LwQ, BsmtFinType1_Rec, BsmtFinType1_Unf, BsmtFinType2_BLQ, BsmtFinType2_GLQ, BsmtFinType2_LwQ, BsmtFinType2_Rec, BsmtFinType2_Unf, Heating_GasA, Heating_GasW, Heating_Grav, Heating_OthW, Heating_Wall, HeatingQC_Fa, HeatingQC_Gd, HeatingQC_Po, HeatingQC_TA, CentralAir_Y, Electrical_FuseF, Electrical_FuseP, Electrical_Mix, Electrical_SBrkr, KitchenQual_Fa, KitchenQual_Gd, KitchenQual_TA, Functional_Maj2, Functional_Min1, Functional_Min2, Functional_Mod, Functional_Sev, Functional_Typ, FireplaceQu_Fa, FireplaceQu_Gd, FireplaceQu_Po, FireplaceQu_TA, GarageType_Attchd, GarageType_Basment, GarageType_BuiltIn, GarageType_CarPort, GarageType_Detchd, GarageFinish_RFn, GarageFinish_Unf, GarageQual_Fa, GarageQual_Gd, GarageQual_Po, GarageQual_TA, GarageCond_Fa, GarageCond_Gd, GarageCond_Po, GarageCond_TA, PavedDrive_P, PavedDrive_Y, PoolQC_Fa, PoolQC_Gd, Fence_GdWo, Fence_MnPrv, Fence_MnWw, MiscFeature_Othr, MiscFeature_Shed, MiscFeature_TenC, SaleType_CWD, SaleType_Con, SaleType_ConLD, SaleType_ConLI, SaleType_ConLw, SaleType_New, SaleType_Oth, SaleType_WD, SaleCond ...
# Start: score=29617.00, constant
# Step: score=28458.95, add OverallQual
# Step: score=28166.67, add GrLivArea
# Step: score=28056.34, add BsmtFinSF1
# Step: score=27970.11, add GarageCars
# Step: score=27899.12, add Condition2_PosN
# Step: score=27815.14, add PoolQC_Gd
# Step: score=27749.03, add SaleType_New
# Step: score=27695.55, add MSSubClass
# Step: score=27655.93, add BsmtExposure_Gd
# Step: score=27617.53, add Neighborhood_NridgHt
# Step: score=27568.00, add Neighborhood_StoneBr
# Step: score=27509.84, add Neighborhood_NoRidge
# Step: score=27476.97, add YearBuilt
# Step: score=27427.45, add OverallCond
# Step: score=27389.46, add RoofMatl_WdShngl
# Step: score=27366.74, add LotArea
# Step: score=27344.44, add Neighborhood_Crawfor
# Step: score=27321.96, add BsmtQual_Gd
# Step: score=27300.52, add BsmtQual_TA
# Step: score=27280.78, add Condition1_Norm
# Step: score=27259.37, add Neighborhood_Somerst
# Step: score=27240.18, add RoofMatl_CompShg
# Step: score=27222.41, add PoolArea
# Step: score=27200.12, add PoolQC_Fa
# Step: score=27187.89, add TotalBsmtSF
# Step: score=27173.76, add BldgType_Duplex
# Step: score=27162.45, add Functional_Typ
# Step: score=27150.40, add LotConfig_CulDSac
# Step: score=27138.23, add BsmtFullBath
# Step: score=27126.16, add KitchenQual_Gd
# Step: score=27078.80, add KitchenQual_TA
# Step: score=27068.35, add KitchenQual_Fa
# Step: score=27058.65, add SaleCondition_Normal
# Step: score=27049.84, add BsmtExposure_No
# Step: score=27041.29, add RoofMatl_WdShake
# Step: score=27031.03, add RoofMatl_Tar&Grv
# Step: score=26996.51, add RoofMatl_Membran
# Step: score=26799.07, add RoofMatl_Roll
# Step: score=26787.27, add Neighborhood_BrkSide
# Step: score=26776.36, add 2ndFlrSF
# Step: score=26764.72, add LandContour_Low
# Step: score=26753.41, add Exterior1st_BrkFace
# Step: score=26743.48, add BedroomAbvGr
# Step: score=26735.68, add BsmtQual_Fa
# Step: score=26728.24, add Condition2_PosA
# Step: score=26720.75, add LotShape_IR2
# Step: score=26712.23, add MasVnrArea
# Step: score=26707.58, add WoodDeckSF
# Step: score=26702.05, add ScreenPorch
# Step: score=26696.64, add GarageYrBlt
# Step: score=26692.41, add BsmtFinType1_GLQ
# Step: score=26688.54, add 1stFlrSF
# Step: score=26684.11, add MasVnrType_BrkFace
# Step: score=26680.00, add Foundation_Wood
# Step: score=26676.27, add KitchenAbvGr
# Step: score=26670.71, add BldgType_2fmCon
# Step: score=26664.66, add Street_Pave
# Step: score=26660.85, add TotRmsAbvGrd
# Step: score=26657.30, add HouseStyle_SLvl
# Step: score=26655.57, add Exterior2nd_Stone
# Step: score=26654.04, add Condition1_RRAn
# Step: score=26652.57, add Exterior2nd_BrkFace
# Step: score=26651.21, add Heating_Wall
# Step: score=26649.89, add ExterQual_Gd
# Step: score=26629.53, add ExterQual_TA
# Step: score=26626.33, add ExterQual_Fa
# Step: score=26624.69, add YearRemodAdd
# Step: score=26623.55, add HeatingQC_Gd
# Step: score=26622.30, add BsmtCond_TA
# Step: score=26620.84, add Functional_Sev
# Step: score=26619.25, add LandSlope_Sev
# Step: score=26617.90, add BsmtFinSF2
# Step: score=26616.77, add HeatingQC_TA
# Step: score=26616.11, add SaleType_CWD
# Step: score=26615.21, add BsmtFinType2_LwQ
# Step: score=26614.51, add BsmtCond_Po
# Step: score=26614.26, add MSZoning_FV
# Step: score=26613.97, add Neighborhood_Mitchel
# Step: score=26613.55, add Condition1_RRAe
# Step: score=26612.72, add Neighborhood_SawyerW
# Step: score=26612.22, add YrSold
# Step: score=26612.07, add Fireplaces
# Step: score=26611.82, add Exterior2nd_Plywood
# Step: score=26611.50, add Fence_MnPrv
# Step: score=26611.42, add BsmtHalfBath
# Step: score=26611.36, add Exterior2nd_ImStucc
# Step: score=26611.36, add None

# %%
# 2 Forward Selection results:
print(best_variables)
regressionSummary(y_test, best_model.predict(x_test[best_variables]))
# Out:
# ['OverallQual', 'GrLivArea', 'BsmtFinSF1', 'GarageCars', 'Condition2_PosN', 'PoolQC_Gd', 'SaleType_New', 'MSSubClass', 'BsmtExposure_Gd', 'Neighborhood_NridgHt', 'Neighborhood_StoneBr', 'Neighborhood_NoRidge', 'YearBuilt', 'OverallCond', 'RoofMatl_WdShngl', 'LotArea', 'Neighborhood_Crawfor', 'BsmtQual_Gd', 'BsmtQual_TA', 'Condition1_Norm', 'Neighborhood_Somerst', 'RoofMatl_CompShg', 'PoolArea', 'PoolQC_Fa', 'TotalBsmtSF', 'BldgType_Duplex', 'Functional_Typ', 'LotConfig_CulDSac', 'BsmtFullBath', 'KitchenQual_Gd', 'KitchenQual_TA', 'KitchenQual_Fa', 'SaleCondition_Normal', 'BsmtExposure_No', 'RoofMatl_WdShake', 'RoofMatl_Tar&Grv', 'RoofMatl_Membran', 'RoofMatl_Roll', 'Neighborhood_BrkSide', '2ndFlrSF', 'LandContour_Low', 'Exterior1st_BrkFace', 'BedroomAbvGr', 'BsmtQual_Fa', 'Condition2_PosA', 'LotShape_IR2', 'MasVnrArea', 'WoodDeckSF', 'ScreenPorch', 'GarageYrBlt', 'BsmtFinType1_GLQ', '1stFlrSF', 'MasVnrType_BrkFace', 'Foundation_Wood', 'KitchenAbvGr', 'BldgType_2fmCon', 'Street_Pave', 'TotRmsAbvGrd', 'HouseStyle_SLvl', 'Exterior2nd_Stone', 'Condition1_RRAn', 'Exterior2nd_BrkFace', 'Heating_Wall', 'ExterQual_Gd', 'ExterQual_TA', 'ExterQual_Fa', 'YearRemodAdd', 'HeatingQC_Gd', 'BsmtCond_TA', 'Functional_Sev', 'LandSlope_Sev', 'BsmtFinSF2', 'HeatingQC_TA', 'SaleType_CWD', 'BsmtFinType2_LwQ', 'BsmtCond_Po', 'MSZoning_FV', 'Neighborhood_Mitchel', 'Condition1_RRAe', 'Neighborhood_SawyerW', 'YrSold', 'Fireplaces', 'Exterior2nd_Plywood', 'Fence_MnPrv', 'BsmtHalfBath', 'Exterior2nd_ImStucc']
#
# Regression statistics
#
#                       Mean Error (ME) : 2692.8452
#        Root Mean Squared Error (RMSE) : 52093.8414
#             Mean Absolute Error (MAE) : 20286.6344
#           Mean Percentage Error (MPE) : 0.1884
# Mean Absolute Percentage Error (MAPE) : 11.4996

# %%
# Feature engineering
# 3 Stepwise Selection/?Regression? (just additional code to the forward selection):
best_model, best_variables = stepwise_selection(x_train.columns, train_model, score_model, verbose=True)
# Out:
# Variables: Id, MSSubClass, LotFrontage, LotArea, OverallQual, OverallCond, YearBuilt, YearRemodAdd, MasVnrArea, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, TotRmsAbvGrd, Fireplaces, GarageYrBlt, GarageCars, GarageArea, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, MSZoning_FV, MSZoning_RH, MSZoning_RL, MSZoning_RM, Street_Pave, Alley_Pave, LotShape_IR2, LotShape_IR3, LotShape_Reg, LandContour_HLS, LandContour_Low, LandContour_Lvl, Utilities_NoSeWa, LotConfig_CulDSac, LotConfig_FR2, LotConfig_FR3, LotConfig_Inside, LandSlope_Mod, LandSlope_Sev, Neighborhood_Blueste, Neighborhood_BrDale, Neighborhood_BrkSide, Neighborhood_ClearCr, Neighborhood_CollgCr, Neighborhood_Crawfor, Neighborhood_Edwards, Neighborhood_Gilbert, Neighborhood_IDOTRR, Neighborhood_MeadowV, Neighborhood_Mitchel, Neighborhood_NAmes, Neighborhood_NPkVill, Neighborhood_NWAmes, Neighborhood_NoRidge, Neighborhood_NridgHt, Neighborhood_OldTown, Neighborhood_SWISU, Neighborhood_Sawyer, Neighborhood_SawyerW, Neighborhood_Somerst, Neighborhood_StoneBr, Neighborhood_Timber, Neighborhood_Veenker, Condition1_Feedr, Condition1_Norm, Condition1_PosA, Condition1_PosN, Condition1_RRAe, Condition1_RRAn, Condition1_RRNe, Condition1_RRNn, Condition2_Feedr, Condition2_Norm, Condition2_PosA, Condition2_PosN, Condition2_RRAe, Condition2_RRAn, Condition2_RRNn, BldgType_2fmCon, BldgType_Duplex, BldgType_Twnhs, BldgType_TwnhsE, HouseStyle_1.5Unf, HouseStyle_1Story, HouseStyle_2.5Fin, HouseStyle_2.5Unf, HouseStyle_2Story, HouseStyle_SFoyer, HouseStyle_SLvl, RoofStyle_Gable, RoofStyle_Gambrel, RoofStyle_Hip, RoofStyle_Mansard, RoofStyle_Shed, RoofMatl_CompShg, RoofMatl_Membran, RoofMatl_Metal, RoofMatl_Roll, RoofMatl_Tar&Grv, RoofMatl_WdShake, RoofMatl_WdShngl, Exterior1st_AsphShn, Exterior1st_BrkComm, Exterior1st_BrkFace, Exterior1st_CBlock, Exterior1st_CemntBd, Exterior1st_HdBoard, Exterior1st_ImStucc, Exterior1st_MetalSd, Exterior1st_Plywood, Exterior1st_Stone, Exterior1st_Stucco, Exterior1st_VinylSd, Exterior1st_Wd Sdng, Exterior1st_WdShing, Exterior2nd_AsphShn, Exterior2nd_Brk Cmn, Exterior2nd_BrkFace, Exterior2nd_CBlock, Exterior2nd_CmentBd, Exterior2nd_HdBoard, Exterior2nd_ImStucc, Exterior2nd_MetalSd, Exterior2nd_Other, Exterior2nd_Plywood, Exterior2nd_Stone, Exterior2nd_Stucco, Exterior2nd_VinylSd, Exterior2nd_Wd Sdng, Exterior2nd_Wd Shng, MasVnrType_BrkFace, MasVnrType_None, MasVnrType_Stone, ExterQual_Fa, ExterQual_Gd, ExterQual_TA, ExterCond_Fa, ExterCond_Gd, ExterCond_Po, ExterCond_TA, Foundation_CBlock, Foundation_PConc, Foundation_Slab, Foundation_Stone, Foundation_Wood, BsmtQual_Fa, BsmtQual_Gd, BsmtQual_TA, BsmtCond_Gd, BsmtCond_Po, BsmtCond_TA, BsmtExposure_Gd, BsmtExposure_Mn, BsmtExposure_No, BsmtFinType1_BLQ, BsmtFinType1_GLQ, BsmtFinType1_LwQ, BsmtFinType1_Rec, BsmtFinType1_Unf, BsmtFinType2_BLQ, BsmtFinType2_GLQ, BsmtFinType2_LwQ, BsmtFinType2_Rec, BsmtFinType2_Unf, Heating_GasA, Heating_GasW, Heating_Grav, Heating_OthW, Heating_Wall, HeatingQC_Fa, HeatingQC_Gd, HeatingQC_Po, HeatingQC_TA, CentralAir_Y, Electrical_FuseF, Electrical_FuseP, Electrical_Mix, Electrical_SBrkr, KitchenQual_Fa, KitchenQual_Gd, KitchenQual_TA, Functional_Maj2, Functional_Min1, Functional_Min2, Functional_Mod, Functional_Sev, Functional_Typ, FireplaceQu_Fa, FireplaceQu_Gd, FireplaceQu_Po, FireplaceQu_TA, GarageType_Attchd, GarageType_Basment, GarageType_BuiltIn, GarageType_CarPort, GarageType_Detchd, GarageFinish_RFn, GarageFinish_Unf, GarageQual_Fa, GarageQual_Gd, GarageQual_Po, GarageQual_TA, GarageCond_Fa, GarageCond_Gd, GarageCond_Po, GarageCond_TA, PavedDrive_P, PavedDrive_Y, PoolQC_Fa, PoolQC_Gd, Fence_GdWo, Fence_MnPrv, Fence_MnWw, MiscFeature_Othr, MiscFeature_Shed, MiscFeature_TenC, SaleType_CWD, SaleType_Con, SaleType_ConLD, SaleType_ConLI, SaleType_ConLw, SaleType_New, SaleType_Oth, SaleType_WD, SaleCond ...
# Start: score=29617.00, constant
# Step: score=28458.95, add OverallQual
# Step: score=28166.67, add GrLivArea
# Step: score=28056.34, add BsmtFinSF1
# Step: score=27970.11, add GarageCars
# Step: score=27899.12, add Condition2_PosN
# Step: score=27815.14, add PoolQC_Gd
# Step: score=27749.03, add SaleType_New
# Step: score=27695.55, add MSSubClass
# Step: score=27655.93, add BsmtExposure_Gd
# Step: score=27617.53, add Neighborhood_NridgHt
# Step: score=27568.00, add Neighborhood_StoneBr
# Step: score=27509.84, add Neighborhood_NoRidge
# Step: score=27476.97, add YearBuilt
# Step: score=27427.45, add OverallCond
# Step: score=27389.46, add RoofMatl_WdShngl
# Step: score=27366.74, add LotArea
# Step: score=27344.44, add Neighborhood_Crawfor
# Step: score=27321.96, add BsmtQual_Gd
# Step: score=27300.52, add BsmtQual_TA
# Step: score=27280.78, add Condition1_Norm
# Step: score=27259.37, add Neighborhood_Somerst
# Step: score=27240.18, add RoofMatl_CompShg
# Step: score=27222.41, add PoolArea
# Step: score=27200.12, add PoolQC_Fa
# Step: score=27187.89, add TotalBsmtSF
# Step: score=27173.76, add BldgType_Duplex
# Step: score=27162.45, add Functional_Typ
# Step: score=27150.40, add LotConfig_CulDSac
# Step: score=27138.23, add BsmtFullBath
# Step: score=27126.16, add KitchenQual_Gd
# Step: score=27078.80, add KitchenQual_TA
# Step: score=27068.35, add KitchenQual_Fa
# Step: score=27058.65, add SaleCondition_Normal
# Step: score=27049.84, add BsmtExposure_No
# Step: score=27041.29, add RoofMatl_WdShake
# Step: score=27031.03, add RoofMatl_Tar&Grv
# Step: score=26996.51, add RoofMatl_Membran
# Step: score=26799.07, add RoofMatl_Roll
# Step: score=26787.27, add Neighborhood_BrkSide
# Step: score=26776.36, add 2ndFlrSF
# Step: score=26764.72, add LandContour_Low
# Step: score=26753.41, add Exterior1st_BrkFace
# Step: score=26743.48, add BedroomAbvGr
# Step: score=26735.68, add BsmtQual_Fa
# Step: score=26728.24, add Condition2_PosA
# Step: score=26720.75, add LotShape_IR2
# Step: score=26712.23, add MasVnrArea
# Step: score=26707.58, add WoodDeckSF
# Step: score=26702.05, add ScreenPorch
# Step: score=26696.64, add GarageYrBlt
# Step: score=26692.41, add BsmtFinType1_GLQ
# Step: score=26688.54, add 1stFlrSF
# Step: score=26684.11, add MasVnrType_BrkFace
# Step: score=26680.00, add Foundation_Wood
# Step: score=26676.27, add KitchenAbvGr
# Step: score=26670.71, add BldgType_2fmCon
# Step: score=26664.66, add Street_Pave
# Step: score=26660.85, add TotRmsAbvGrd
# Step: score=26657.30, add HouseStyle_SLvl
# Step: score=26655.43, remove BldgType_Duplex
# Step: score=26653.69, remove BsmtFullBath
# Step: score=26652.01, add Exterior2nd_Stone
# Step: score=26650.48, add Condition1_RRAn
# Step: score=26649.07, add Exterior2nd_BrkFace
# Step: score=26647.87, add MSZoning_FV
# Step: score=26646.71, add Heating_Wall
# Step: score=26645.42, add YearRemodAdd
# Step: score=26643.75, add ExterQual_Gd
# Step: score=26623.52, add ExterQual_TA
# Step: score=26620.54, add ExterQual_Fa
# Step: score=26619.25, add HeatingQC_Gd
# Step: score=26617.92, add HeatingQC_TA
# Step: score=26616.86, add Neighborhood_SawyerW
# Step: score=26615.77, add SaleType_CWD
# Step: score=26614.87, remove GrLivArea
# Step: score=26614.10, add Condition1_RRAe
# Step: score=26613.41, add BsmtCond_TA
# Step: score=26612.48, add Functional_Sev
# Step: score=26611.20, add LandSlope_Sev
# Step: score=26610.06, add BsmtUnfSF
# Step: score=26609.31, add BsmtCond_Po
# Step: score=26608.57, add BsmtFinType2_LwQ
# Step: score=26608.14, add YrSold
# Step: score=26607.64, add Neighborhood_Mitchel
# Step: score=26607.45, add Fireplaces
# Step: score=26607.23, add GarageType_Attchd
# Step: score=26606.82, add Condition2_RRAe
# Step: score=26601.53, add RoofStyle_Shed
# Step: score=26601.20, remove BsmtFinSF1
# Step: score=26600.78, add Exterior2nd_Plywood
# Step: score=26600.44, add MasVnrType_Stone
# Step: score=26600.16, add BsmtHalfBath
# Step: score=26599.92, remove Neighborhood_Somerst
# Step: score=26599.36, add Exterior2nd_ImStucc
# Step: score=26599.05, add BsmtFinType2_Rec
# Step: score=26598.64, add RoofStyle_Mansard
# Step: score=26598.08, add Exterior2nd_Wd Shng
# Step: score=26597.77, add Heating_GasA
# Step: score=26597.43, add Exterior1st_ImStucc
# Step: score=26597.12, add FireplaceQu_Gd
# Step: score=26596.93, remove Condition1_RRAn
# Step: score=26596.79, add GarageQual_Fa
# Step: score=26594.54, add GarageQual_TA
# Step: score=26591.49, add GarageQual_Gd
# Step: score=26587.58, add GarageQual_Po
# Step: score=26587.18, add MSZoning_RL
# Step: score=26586.34, add Neighborhood_Edwards
# Step: score=26583.67, add Neighborhood_NAmes
# Step: score=26581.48, add Neighborhood_NWAmes
# Step: score=26581.36, remove Heating_GasA
# Step: score=26581.21, remove SaleType_CWD
# Step: score=26581.07, remove Neighborhood_SawyerW
# Step: score=26581.07, unchanged None

# %%
# 3 Stepwise Selection results:
print(best_variables)
regressionSummary(y_test, best_model.predict(x_test[best_variables]))
# Out:
# ['OverallQual', 'GarageCars', 'Condition2_PosN', 'PoolQC_Gd', 'SaleType_New', 'MSSubClass', 'BsmtExposure_Gd', 'Neighborhood_NridgHt', 'Neighborhood_StoneBr', 'Neighborhood_NoRidge', 'YearBuilt', 'OverallCond', 'RoofMatl_WdShngl', 'LotArea', 'Neighborhood_Crawfor', 'BsmtQual_Gd', 'BsmtQual_TA', 'Condition1_Norm', 'RoofMatl_CompShg', 'PoolArea', 'PoolQC_Fa', 'TotalBsmtSF', 'Functional_Typ', 'LotConfig_CulDSac', 'KitchenQual_Gd', 'KitchenQual_TA', 'KitchenQual_Fa', 'SaleCondition_Normal', 'BsmtExposure_No', 'RoofMatl_WdShake', 'RoofMatl_Tar&Grv', 'RoofMatl_Membran', 'RoofMatl_Roll', 'Neighborhood_BrkSide', '2ndFlrSF', 'LandContour_Low', 'Exterior1st_BrkFace', 'BedroomAbvGr', 'BsmtQual_Fa', 'Condition2_PosA', 'LotShape_IR2', 'MasVnrArea', 'WoodDeckSF', 'ScreenPorch', 'GarageYrBlt', 'BsmtFinType1_GLQ', '1stFlrSF', 'MasVnrType_BrkFace', 'Foundation_Wood', 'KitchenAbvGr', 'BldgType_2fmCon', 'Street_Pave', 'TotRmsAbvGrd', 'HouseStyle_SLvl', 'Exterior2nd_Stone', 'Exterior2nd_BrkFace', 'MSZoning_FV', 'Heating_Wall', 'YearRemodAdd', 'ExterQual_Gd', 'ExterQual_TA', 'ExterQual_Fa', 'HeatingQC_Gd', 'HeatingQC_TA', 'Condition1_RRAe', 'BsmtCond_TA', 'Functional_Sev', 'LandSlope_Sev', 'BsmtUnfSF', 'BsmtCond_Po', 'BsmtFinType2_LwQ', 'YrSold', 'Neighborhood_Mitchel', 'Fireplaces', 'GarageType_Attchd', 'Condition2_RRAe', 'RoofStyle_Shed', 'Exterior2nd_Plywood', 'MasVnrType_Stone', 'BsmtHalfBath', 'Exterior2nd_ImStucc', 'BsmtFinType2_Rec', 'RoofStyle_Mansard', 'Exterior2nd_Wd Shng', 'Exterior1st_ImStucc', 'FireplaceQu_Gd', 'GarageQual_Fa', 'GarageQual_TA', 'GarageQual_Gd', 'GarageQual_Po', 'MSZoning_RL', 'Neighborhood_Edwards', 'Neighborhood_NAmes', 'Neighborhood_NWAmes']
#
# Regression statistics
#
#                       Mean Error (ME) : 2635.9420
#        Root Mean Squared Error (RMSE) : 53590.1160
#             Mean Absolute Error (MAE) : 20598.5076
#           Mean Percentage Error (MPE) : 0.1717
# Mean Absolute Percentage Error (MAPE) : 11.7664

# %% [markdown]
# # Exhaustive Search
# #train
# s=linear.fit(x_train,y_train)
# def score_model(model,):
#     pred_y = model.predict(x_test)
#     # we negate as score is optimized to be as low as possible
#     return -adjusted_r2_score(y_test, pred_y,model)
#
# allVariables = ds.drop(predict,axis=1).columns
# def train_model(allVariables):
#     model = linear_model.LinearRegression()
#     model.fit(x_train, y_train)
#     return model
#
# def score_model(model,allVariables):
#     pred_y = model.predict(x_test)
#     # we negate as score is optimized to be as low as possible
#     return -adjusted_r2_score(y_test, pred_y, model)
#
#
# results = exhaustive_search(allVariables, train_model, score_model)
# results
#
# data = []
# for result in results:
#     model = result['model']
#     allV = list(result['allV'])
#     AIC = AIC_score(y_test, model.predict(x_test), model)
#     d = {'n': result['n'], 'r2adj': -result['score'], 'AIC': AIC}
#     d.update({var: var in result['allV'] for var in allVariables})
#     data.append(d)
# pd.DataFrame(data, columns=('n', 'r2adj', 'AIC') + tuple(sorted(allVariables)))
